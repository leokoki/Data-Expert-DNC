# %% [markdown]
# # <center><font color='green'><b>Deliverable 01 - Slot 03</b></font></center>
#
# <center>Mini Projeto - Roof Imóveis</center>

# %% [markdown]
# ## 1 - **Importando:**

# %% [markdown]
# ### 1.1 - Bibliotecas utilizadas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Conexão com Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 1.2 - Dados do Kaggle

# %%
#Kaggle
df = pd.read_csv('/content/drive/MyDrive/DNC/Day 3/Deliverable/Data/kaggle_kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ### 1.3 - Tamanho e DataTypes

# %%
len(df)
# Out:
# 21613

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ## 2 - **A Coleta de Dados:**

# %% [markdown]
# ### 2.1 - Análise da Qualidade dos Dados
# ![MetaDados.png]("https://ibb.co/v4jYXBg")

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
df.describe()
# Out:
#                  id      price  bedrooms  bathrooms  sqft_living   sqft_lot  \
# count      21613.00   21613.00  21613.00   21613.00     21613.00   21613.00
# mean  4580301520.86  540088.14      3.37       2.11      2079.90   15106.97
# std   2876565571.31  367127.20      0.93       0.77       918.44   41420.51
# min      1000102.00   75000.00      0.00       0.00       290.00     520.00
# 25%   2123049194.00  321950.00      3.00       1.75      1427.00    5040.00
# 50%   3904930410.00  450000.00      3.00       2.25      1910.00    7618.00
# 75%   7308900445.00  645000.00      4.00       2.50      2550.00   10688.00
# max   9900000190.00 7700000.00     33.00       8.00     13540.00 1651359.00
#
#         floors  waterfront     view  condition    grade  sqft_above  \
# count 21613.00    21613.00 21613.00   21613.00 21613.00    21613.00
# mean      1.49        0.01     0.23       3.41     7.66     1788.39
# std       0.54        0.09     0.77       0.65     1.18      828.09
# ...
