# %%
import pandas as pd
import numpy as np

# %%
data =  {"Nome": ["Nicolas","Daniel","Julia"],"Idade": [25,29,23],"Cidade":["São José","São Paulo","BH"]}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#       Nome  Idade     Cidade
# 0  Nicolas     25   São José
# 1   Daniel     29  São Paulo
# 2    Julia     23         BH

# %%
df.dtypes
# Out:
# Nome      object
# Idade      int64
# Cidade    object
# dtype: object

# %%
df.shape
# Out:
# (3, 3)

# %%
df.describe()
# Out:
#            Idade
# count   3.000000
# mean   25.666667
# std     3.055050
# min    23.000000
# 25%    24.000000
# 50%    25.000000
# 75%    27.000000
# max    29.000000

# %%
df.describe(include=object)
# Out:
#            Nome    Cidade
# count         3         3
# unique        3         3
# top     Nicolas  São José
# freq          1         1

# %%
df.describe(include='all')
# Out:
#            Nome      Idade    Cidade
# count         3   3.000000         3
# unique        3        NaN         3
# top     Nicolas        NaN  São José
# freq          1        NaN         1
# mean        NaN  25.666667       NaN
# std         NaN   3.055050       NaN
# min         NaN  23.000000       NaN
# 25%         NaN  24.000000       NaN
# 50%         NaN  25.000000       NaN
# 75%         NaN  27.000000       NaN
# max         NaN  29.000000       NaN

# %%
from google.colab import drive
drive.mount('/content/drive')
arq = '/content/drive/MyDrive/DNC/Day 3/Aula/Salary Dataset.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(arq)

# %%
]
